# %% [markdown]
# # Conditionals Statment
# - Helps you to code decision based on some preconditions.
# - 1. if
#   2. else
#   3. elif
#   4. nested if else
#
# ## Syntax
# - if Condition True:
# -     block of code will be executed.

# %%
a=100
if a >0:
    print("The number is greater than zero.")
# Out:
# The number is greater than zero.

# %%
a=100
if a <0:
    print("The number is greater than zero.")
else:
    print("The number is less")
# Out:
# The number is less

# %%
weather ='rainy'
if weather == 'rainy':
    print("I will not play cricket")
# Out:
# I will not play cricket

# %%
tem=35
if tem >25:
    print("Room Temp")
# Out:
# Room Temp

# %%
is_ds_course= True
if is_ds_course:
    print("Im studying")
# Out:
# Im studying

# %%
number= 42
if number %2==0:
    print("Even Number")
# Out:
# Even Number

# %%
num=42
if ((num%2==0) & (num>0)):
    print("This is the number of interest")
# Out:
# This is the number of interest

# %%
num=42
if num%2==0 and num>0:
    print("This is the number of interest")
# Out:
# This is the number of interest

# %%
weather ='rainy'
if weather == 'rainy':
    print("I will not play cricket")
else:
    print("I will watch TV")
# Out:
# I will not play cricket

# %%
weather ='sunny'
if weather == 'sunny':
    print("I will  play cricket")
else:
    print("I will watch TV")
# Out:
# I will  play cricket

# %%
age=21
if age>=18:
    print("Drink will be serverd")
else:
    print("Go out")
# Out:
# Drink will be serverd

# %%
# Even odd
num=18
if num%2==0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %%
a=10
if a>100:
    print("Execute this")
elif a<100:
    print("Elif Executed")
else:
    print("The number os equal to 100")
# Out:
# Elif Executed

# %%
age=80
if age<18:
    print("You are minor")
elif 18<age<=65:
    print('Adult')
else:
    print("Senior Citizen")
# Out:
# Senior Citizen

# %% [markdown]
# # Nested if else

# %%
x=1
y=6
if x>5:
    if y>5:
        print("Both are greater")
    else:
        print("Y is less")
else:
    print("X is less")
# Out:
# X is less

# %%
is_vip = False
age = 15
if is_vip:
    if age >=18:
        if age < 65:
            print("welcome to vip customer")
        else: 
            print("You are vip and very imp. YOu are eligible for senior citizen discount")
    else:
        print("Vip staus is only for adult")
else:
    print("You are not a vip customer and will be charged a regular price")
# Out:
# You are not a vip customer and will be charged a regular price

# %%
a = int(input("Enter a no"))
if a >= 100:
    print("The no is greater than 100")
elif 0<=a<100:
    print("The no is greater than 0 and less than 100")
else:
    print("This is a negative no")
# Out:
# Enter a no 150
# The no is greater than 100

# %%
name = input("Please enter your name")
email = input("Please enter your email")
password = input("Please eneter your password")

if name == "":
    print("Please enter a valid name, can not be empty")
else:
    if "@" not in email:
        print("Please enter a valid email")
    else:
        if len(password) < 0:
            print("No password entered, pls provide a valid password")
        else:
            print("Login/registration is successfull")
# Out:
# Please enter your name
# Please enter your email jjul
# Please eneter your password ,,
# Please enter a valid name, can not be empty

# %%
for i in range(3,0,-1):
    print(i)
# Out:
# 3
# 2
# 1
