# %% [markdown]
# # Mutability and Immutability
# - Mutability means change-: Object/ Container whose state or value can be changed after they are created are calles as mutable object also called as item assignmet. Example is list
# - Immutability  object -:Object/ Container whose state or value can not  be changed after they are created are called as immutable object. Ex is String.

# %%
a=6
a
# In the memory, a memory block is created wit refrence name a and value 6.
# Out:
# 6

# %%
b='ayush'
b
# Out:
# 'ayush'

# %%
b[0]
# Out:
# 'a'

# %%
b[3]
# Out:
# 's'

# %%
b[-5]
# Out:
# 'a'

# %%
b[-2]
# Out:
# 's'

# %% [markdown]
# # Another type of data container i.e list which can store any type of data like int float string.

# %%
list1=[1,2,3,4.5,3+5j,True,'ayush']
list1
# Out:
# [1, 2, 3, 4.5, (3+5j), True, 'ayush']

# %%
list1[4]
# Out:
# (3+5j)

# %%
list1[-3]
# Out:
# (3+5j)

# %%
list1[2]
# Out:
# 3

# %%
type(list1)
# Out:
# list

# %%
list1[-1]
# Out:
# 'ayush'

# %%
#Mutability
list1[6]='Rahul'

# %%
list1
# Out:
# [1, 2, 3, 4.5, (3+5j), True, 'Rahul']

# %%
list1[0]=100

# %%
list1
# Out:
# [100, 2, 3, 4.5, (3+5j), True, 'Rahul']

# %%
b='pwskills'

# %%
b[0]
# Out:
# 'p'

# %%
b[0]='i'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 b[0]='i'
#
# TypeError: 'str' object does not support item assignment
