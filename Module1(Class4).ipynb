# %% [markdown]
# # Type Casting
# - The process of changing the data type of variable in python is called type casting.

# %%
a=5.6
type(a)
# Out:
# float

# %%
2+3
# Out:
# 5

# %%
'2' +3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 '2' +3
#
# TypeError: can only concatenate str (not "int") to str

# %%
a='2'
b=3
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 a='2'
#       2 b=3
# ----> 3 a+b
#
# TypeError: can only concatenate str (not "int") to str

# %%
type(a)
# Out:
# str

# %%
a='2'
b=3
int(a)+b
# Out:
# 5

# %%
# String to integer
a='2'
print(type(a))
print(type(int(a)))
# Out:
# <class 'str'>
# <class 'int'>

# %%
#Float to integer
a=3.4
type(a)
# Out:
# float

# %%
int(a)
# Out:
# 3

# %%
b=6.78
type(b)
# Out:
# float

# %%
int(b)
# Out:
# 6

# %%
# int to float
a=3
type(a)
# Out:
# int

# %%
# String to float
a="2.3"
type(a)
# Out:
# str

# %%
float(a)
# Out:
# 2.3

# %%
a='ayush'
type(a)
# Out:
# str

# %%
int(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 int(a)
#
# ValueError: invalid literal for int() with base 10: 'ayush'

# %%
# Integer to string
a=5
type(a)
# Out:
# int

# %%
str(a)
# Out:
# '5'

# %% [markdown]
# # Types of casting
# 1. implicit -> Python understand the data type
# 2. explicit -> Convert data type using inbuilt function

# %%
# implicit
a=4
type(a)
# Out:
# int

# %%
#Explicit
a="2.3"
print(type(a))
# Out:
# <class 'str'>

# %%
c=float(a)

# %%
print(c)
# Out:
# 2.3

# %%
a="ayush"
b=" Saxena"
a+b #Concate of string
# Out:
# 'ayush Saxena'

# %%
# boolean type casting
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(100)
# Out:
# True

# %%
bool(-1)
# Out:
# True

# %%
bool("ayush")
# Out:
# True
