# %%
print("Hello World")
# Out:
# Hello World

# %%
a=5
a
# Out:
# 5

# %% [markdown]
# # Variable/ Identifiers
# - These are placeholder where we keep variety of data which we can use to write logic.
# - Variable is also a reserved memory space for storing value.
#
#   ### Number >> int/float
#   ### Characters >> String in python
#   ### True/False >> Boolean
#   ### None
#   ### Complex

# %%
b="ayush"
b
# Out:
# 'ayush'

# %%
type(b)
# Out:
# str

# %%
a=5
a
# Out:
# 5

# %%
type(a)
# Out:
# int

# %%
b=4.5
b
# Out:
# 4.5

# %%
type(b)
# Out:
# float

# %%
c=True

# %%
c
# Out:
# True

# %%
type(c)
# Out:
# bool

# %%
d=False
d
# Out:
# False

# %%
type(d)
# Out:
# bool

# %%
True - False
# Out:
# 1

# %%
True * False
# Out:
# 0

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
False/False

# %%
True/True

# %%
f= None

# %%
f

# %%
type(f)

# %%
d=5+6j

# %%
d

# %%
type(d)

# %%
d.real

# %%
d.imag

# %% [markdown]
# # Rules of defining Variable
# 1. Variable start with a letter or undersocre character.
# 2. Variable can not start with number.
# 3. Variable can not start with predefined keyword.
# 4. No other special character except underscore can be used for defining variable.

# %% [markdown]
# # Types of comment
# 1. Single Line Comment.
# 2. Multiline Comment.

# %% [markdown]
# # Keywords
# - Keywords in python are predefined words that hold specific meaning and have specific purpose.

# %%
help('keywords')

# %%
a=3 # It is statement which means fundemental block of code.
# Statment can be of many type-:
#Expression, Assignment, Condition, statments, Loops.

# %%
a= 3 # Assisgnment 
b=5 # Assignment
a+b #Expression Statment

# %% [markdown]
# # User Input

# %%
name=input("Please enter your name: ")
print(name)

# %%
type(name)

# %%
name=input("Please enter: ")
print(name)

# %%
type(name)

# %%
n=int(input("Enter the number : "))
print(n)

# %%
type(n)

# %%
a='108'
print(type(a))
print(type(int(a))) # It is type casting

# %%
bool(1)

# %%
bool(0)

# %%
a="Ayush"
int(a)
a

# %% [markdown]
# # Python is a case senstive language.

# %%
a=5
A=15
print(a)
print(A)

# %%
#print= 'Ajay'

# %%
print('world') # now print has been assigned with value it will not work according to its property now.
